# %%
from tensorflow.keras.models import load_model

srcnn_model = load_model('/kaggle/input/scrnn-66-model/deeper_srcnn_model.h5')  # Update with your actual path
# Out:
# 2024-07-03 13:29:23.960358: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-03 13:29:23.960554: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-03 13:29:24.132044: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
import cv2
import numpy as np

def preprocess_image(image_path):
    img = cv2.imread(image_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  
    img = img / 255.0  
    img = np.expand_dims(img, axis=0)  
    return img

def upscale_image(model, image):
    generated_image = model.predict(image)
    generated_image = np.clip(generated_image, 0.0, 1.0)  
    generated_image = (generated_image * 255.0).astype(np.uint8)  
    return generated_image

# %%
input_image_path = '/kaggle/input/image-pro/Image_Processing/Pixelated/30242.jpg'  
input_image = preprocess_image(input_image_path)
high_res_image = upscale_image(srcnn_model, input_image)


cv2.imwrite('output_high_res_image5.jpg', cv2.cvtColor(high_res_image[0], cv2.COLOR_RGB2BGR))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# True
